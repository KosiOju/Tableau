# %% [markdown]
# I am deleting video game data for 2017.\
# The data stops at January 2017, as the previous years were full years, having a month in a year claim it is a full year can lead to misleading conlusions once plotted.

# %%
import pandas as pd

# %%
df = pd.read_csv('for_tableau_games_sales_till_jan_2017.csv')

df.head()
# Out:
#    Unnamed: 0                      Name Platform  Year_of_Release  \
# 0           0                Wii Sports      Wii             2006
# 1           1         Super Mario Bros.      NES             1985
# 2           2            Mario Kart Wii      Wii             2008
# 3           3         Wii Sports Resort      Wii             2009
# 4           4  Pokemon Red/Pokemon Blue        G             1996
#
#           Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0        Sports  Nintendo     41.36     28.96      3.77         8.45
# 1      Platform  Nintendo     29.08      3.58      6.81         0.77
# 2        Racing  Nintendo     15.68     12.80      3.79         3.29
# 3        Sports  Nintendo     15.61     10.95      3.28         2.95
# 4  Role-Playing  Nintendo     11.27      8.89     10.22         1.00
#
#    Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count Rating  \
# ...

# %%
df.shape
# Out:
# (17408, 17)

# %% [markdown]
# Need to drop the 'Unnamed: 0' column, forgot to save to csv in the correct manner.

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# Now need to drop the rows where Year of release is 2017!

# %%
df = df.drop(df[df.Year_of_Release == 2017].index)

# %%
df.shape
# Out:
# (17403, 16)

# %% [markdown]
# Only 5/17408 were from 2017, the dataset should be ready for tableau now.

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.54          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %% [markdown]
# Save to CSV now.

# %%
df.to_csv('for_tableau_games_sales_till_2016.csv', index=False)

# %%
new_df = pd.read_csv('for_tableau_games_sales_till_2016.csv')
new_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.54          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %%
new_df.shape
# Out:
# (17403, 16)
