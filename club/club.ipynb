# %% [markdown]
# # Import data

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
club_df = pd.read_csv('club.csv')

club_df.head()
# Out:
#    Unnamed: 0            Club Name Competition Name  Squad Size  \
# 0           0      Manchester City   Premier League          24
# 1           1  Paris Saint-Germain          Ligue 1          36
# 2           2    Manchester United   Premier League          29
# 3           3           Chelsea FC   Premier League          27
# 4           4         Liverpool FC   Premier League          27
#
#    Average Age Of Players  Market Value Of Club In Millions(£)  \
# 0                    27.1                               970.02
# 1                    26.1                               891.18
# 2                    27.9                               820.13
# 3                    26.9                               802.35
# 4                    27.2                               779.85
#
#    Average Market Value Of Players In Millions(£)  \
# 0                                           40.42
# 1                                           24.76
# 2                                           28.28
# 3                                           29.72
# 4                                           28.88
#
#    Market Value Of Top 18 Players In Millions(£)
# 0                                         920.70
# 1                                         801.00
# 2                                         742.50
# 3                                         737.10
# 4                                         715.95

# %%
club_df.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0               Club Name Competition Name  Squad Size  \
# 0            0         Manchester City   Premier League          24
# 1            1     Paris Saint-Germain          Ligue 1          36
# 2            2       Manchester United   Premier League          29
# 3            3              Chelsea FC   Premier League          27
# 4            4            Liverpool FC   Premier League          27
# ..         ...                     ...              ...         ...
# 95          95              Levante UD           LaLiga          27
# 96          96                 FC Metz          Ligue 1          29
# 97          97  Clube Atlético Mineiro          Série A          29
# 98          98        Lokomotiv Moscow     Premier Liga          29
# 99          99               Genoa CFC          Serie A          34
#
#     Average Age Of Players  Market Value Of Club In Millions(£)  \
# 0                     27.1                               970.02
# 1                     26.1                               891.18
# 2                     27.9                               820.13
# 3                     26.9                               802.35
# 4                     27.2                               779.85
# ..                     ...                                  ...
# 95                    28.1                                89.19
# 96                    25.3                                89.19
# 97                    27.5                                88.61
# 98                    25.0                                87.32
# 99                    27.6                                86.94
#
#     Average Market Value Of Players In Millions(£)  \
# 0                                            40.42
# 1                                            24.76
# 2                                            28.28
# 3                                            29.72
# 4                                            28.88
# ..                                             ...
# 95                                            3.30
# 96                                            3.08
# 97                                            3.06
# 98                                            3.01
# 99                                            2.56
#
#     Market Value Of Top 18 Players In Millions(£)
# 0                                          920.70
# 1                                          801.00
# 2                                          742.50
# 3                                          737.10
# 4                                          715.95
# ..                                            ...
# 95                                          82.35
# 96                                          79.74
# 97                                          76.46
# 98                                          77.85
# 99                                          72.27
#
# [100 rows x 8 columns]>

# %%
#check null values

vars_with_na = [
    var for var in club_df.columns
    if club_df[var].isnull().sum() > 0
]

vars_with_na
# Out:
# []

# %% [markdown]
# no null values

# %%
#'Unnamed: 0' does not add anything
club_df = club_df.drop(columns=['Unnamed: 0'])

club_df.head()
# Out:
#              Club Name Competition Name  Squad Size  Average Age Of Players  \
# 0      Manchester City   Premier League          24                    27.1
# 1  Paris Saint-Germain          Ligue 1          36                    26.1
# 2    Manchester United   Premier League          29                    27.9
# 3           Chelsea FC   Premier League          27                    26.9
# 4         Liverpool FC   Premier League          27                    27.2
#
#    Market Value Of Club In Millions(£)  \
# 0                               970.02
# 1                               891.18
# 2                               820.13
# 3                               802.35
# 4                               779.85
#
#    Average Market Value Of Players In Millions(£)  \
# 0                                           40.42
# 1                                           24.76
# 2                                           28.28
# 3                                           29.72
# 4                                           28.88
#
#    Market Value Of Top 18 Players In Millions(£)
# 0                                         920.70
# 1                                         801.00
# 2                                         742.50
# 3                                         737.10
# 4                                         715.95

# %%
#check unique values - is the amount normal for the data?
for i in club_df.columns:
    print(f'{i}: has {len(club_df[i].unique())} values')
# Out:
# Club Name: has 100 values
# Competition Name: has 16 values
# Squad Size: has 13 values
# Average Age Of Players: has 46 values
# Market Value Of Club In Millions(£): has 98 values
# Average Market Value Of Players In Millions(£): has 96 values
# Market Value Of Top 18 Players In Millions(£): has 99 values

# %% [markdown]
# As the data shows the top 100 richest clubs, most clubs here will belong to the top 5 leagues, and some leagues may only feature one club.

# %% [markdown]
# # Save dataset

# %%
club_df.to_csv('new_club.csv', index=False)

# %%
df2 = pd.read_csv('new_club.csv')
df2.head()
# Out:
#              Club Name Competition Name  Squad Size  Average Age Of Players  \
# 0      Manchester City   Premier League          24                    27.1
# 1  Paris Saint-Germain          Ligue 1          36                    26.1
# 2    Manchester United   Premier League          29                    27.9
# 3           Chelsea FC   Premier League          27                    26.9
# 4         Liverpool FC   Premier League          27                    27.2
#
#    Market Value Of Club In Millions(£)  \
# 0                               970.02
# 1                               891.18
# 2                               820.13
# 3                               802.35
# 4                               779.85
#
#    Average Market Value Of Players In Millions(£)  \
# 0                                           40.42
# 1                                           24.76
# 2                                           28.28
# 3                                           29.72
# 4                                           28.88
#
#    Market Value Of Top 18 Players In Millions(£)
# 0                                         920.70
# 1                                         801.00
# 2                                         742.50
# 3                                         737.10
# 4                                         715.95

# %% [markdown]
# now ready for sql.

# %% [markdown]
# # Tableau prep

# %% [markdown]
# When saved as a csv some club and competition names were corrupted leaving athletico madrid to be displayed as: AtlÃ©tico de Madrid.
# This can be easily rectified by searching for all none alphanumerics and replacing them with the correct strings.
#
# STEPS:
# 1. Use club_1.csv to manipulate the dataset
# 2. Apply the changes and save as new_club_1.0.csv ready for SQL again.

# %% [markdown]
# ### 1. Use club_1.csv to manipulate the dataset

# %%
club1_df = pd.read_csv('club_1.csv')
club1_df.head()
# Out:
#          club_name competition_name  squad_size  avg_player_age  \
# 0   1.FSV Mainz 05       Bundesliga          25            25.7
# 1         AC Milan          Serie A          29            26.8
# 2   ACF Fiorentina          Serie A          26            27.0
# 3  AFC Bournemouth     Championship          26            25.7
# 4   Ajax Amsterdam       Eredivisie          25            25.7
#
#    markt_val_of_club_in_mil_£  avg_markt_val_of_player_in_mil_£  \
# 0                          96                                 4
# 1                         429                                15
# 2                         228                                 9
# 3                         104                                 4
# 4                         305                                12
#
#    markt_val_top_18_players_in_mil_£
# 0                                 90
# 1                                390
# 2                                214
# 3                                100
# 4                                283

# %%
club1_df.shape
# Out:
# (100, 7)

# %% [markdown]
# club_name and competition_name are the columns of interest

# %%
#CREATE the FUNCTION
#we want to find the index of the corrupted values so we can replace them

def find_non_alphanum(df, column):
    non_alnum_index = []
    for c in column:
        for i in range(len(df[c])):
            if df[c][i] == 'SÃ¼per Lig':#function does not spot this string otherwise
                non_alnum_index.append(i)
            for z in range(len(df[c][i].split(' '))):
                split_df = df[c][i].split(' ')
                if split_df[z].isalnum() == False:
                    non_alnum_index.append(i)
                    continue
    print(f'length: {len(non_alnum_index)}')
    return non_alnum_index

# %%
#create a list of the indexes for the club and competition columns
club_idx = find_non_alphanum(club1_df,['club_name'])
competition_idx = find_non_alphanum(club1_df,['competition_name'])
# Out:
# length: 6
# length: 0

# %%
#print club names that need correcting
for i in club_idx:
    print(club1_df['club_name'][i])
# Out:
# 1.FSV Mainz 05
# AS Saint-Etienne
# Brighton & Hove Albion
# Galatasaray A.S.
# Paris Saint-Germain
# Zenit St. Petersburg

# %% [markdown]
# not all of the above are corrupted.

# %%
#show competition names that need correcting
#had to print the whole row so I know what country the competition takes place in.
club1_df.iloc[competition_idx]
# Out:
# Empty DataFrame
# Columns: [club_name, competition_name, squad_size, avg_player_age, markt_val_of_club_in_mil_£, avg_markt_val_of_player_in_mil_£, markt_val_top_18_players_in_mil_£]
# Index: []

# %%
#create a list of the errors and the correct values
club_error = ['AS Saint-Ã‰tienne', 'AtlÃ©tico de Madrid', 'Borussia MÃ¶nchengladbach',
                   'Club AtlÃ©tico River Plate', 'Clube AtlÃ©tico Mineiro', 'Real Betis BalompiÃ©']
club_correct = ['AS Saint-Etienne', 'Atletico de Madrid', 'Borussia Monchengladbach',
                   'Club Atletico River Plate', 'Clube Atletico Mineiro', 'Real Betis Balompie']

comp_error = ['SÃ©rie A', '1.HNL', 'SÃ¼per Lig']
comp_correct = ['Brasileiro Serie A', 'Prva HNL', 'Turkish Super Lig']

def create_dict(key_list, val_list):
    zip_lists = zip(key_list, val_list)
    new_dict = dict(zip_lists)
    
    return new_dict

# %%
import warnings
warnings.filterwarnings('ignore')
#import warning here to hide my path file name

#correct the errors
club_dict = create_dict(club_error, club_correct)
comp_dict = create_dict(comp_error, comp_correct)

for i in club_idx:
    if club1_df['club_name'][i] in club_dict:
        club1_df['club_name'][i] = club_dict[club1_df['club_name'][i]]

for i in competition_idx:
    if club1_df['competition_name'][i] in comp_dict:
        club1_df['competition_name'][i] = comp_dict[club1_df['competition_name'][i]]

# %%
pd.set_option('display.max_rows', None) #displays all rows to check before exporting
club1_df
# Out:
#                         club_name    competition_name  squad_size  \
# 0                  1.FSV Mainz 05          Bundesliga          25
# 1                        AC Milan             Serie A          29
# 2                  ACF Fiorentina             Serie A          26
# 3                 AFC Bournemouth        Championship          26
# 4                  Ajax Amsterdam          Eredivisie          25
# 5                      Arsenal FC      Premier League          26
# 6                       AS Monaco             Ligue 1          29
# 7                         AS Roma             Serie A          30
# 8                AS Saint-Etienne             Ligue 1          27
# 9                     Aston Villa      Premier League          25
# 10                    Atalanta BC             Serie A          26
# 11                Athletic Bilbao              LaLiga          26
# 12             Atletico de Madrid              LaLiga          22
# 13            Bayer 04 Leverkusen          Bundesliga          28
# 83                       SS Lazio             Serie A          33
# 84                     SSC Napoli             Serie A          26
# 85               Stade Rennais FC             Ligue 1          28
# 86                      Torino FC             Serie A          30
# 87              Tottenham Hotspur      Premier League          24
# 88            TSG 1899 Hoffenheim          Bundesliga          33
# 89                   UC Sampdoria             Serie A          27
# 90                 Udinese Calcio             Serie A          26
# 91                    US Sassuolo             Serie A          27
# 92                    Valencia CF              LaLiga          27
# 93                  VfB Stuttgart          Bundesliga          33
# 94                  VfL Wolfsburg          Bundesliga          32
# 95                  Villarreal CF              LaLiga          26
# 96                     Watford FC      Premier League          27
# 97                West Ham United      Premier League          24
# 98        Wolverhampton Wanderers      Premier League          24
# 99           Zenit St. Petersburg        Premier Liga          22
#
#     avg_player_age  markt_val_of_club_in_mil_£  \
# 0             25.7                          96
# 1             26.8                         429
# 2             27.0                         228
# 3             25.7                         104
# 4             25.7                         305
# 5             25.4                         507
# 6             24.4                         331
# 7             25.2                         386
# 8             24.3                          90
# 9             25.6                         372
# 10            27.3                         374
# 11            26.5                         182
# 12            28.2                         671
# 13            24.6                         349
# 14            26.1                         756
# 15            27.8                         114
# 16            25.9                         131
# 17            24.8                         544
# 18            25.6                         244
# 19            24.6                         180
# 20            25.7                         232
# 21            30.1                         131
# 22            27.4                         132
# 23            27.8                         127
# 24            26.9                         802
# 25            27.9                         100
# 26            24.3                         150
# 27            27.5                          89
# 28            27.4                         134
# 29            27.6                         225
# 30            25.6                         120
# 31            25.6                         180
# 32            28.0                         386
# 33            25.9                         592
# 34            25.3                          90
# 35            25.3                          89
# 36            26.6                         239
# 37            25.5                         114
# 38            23.6                         101
# 39            27.8                         102
# 40            26.8                         133
# 41            26.8                          99
# 42            27.6                          87
# 43            27.3                         141
# 44            26.1                          99
# 45            26.9                          98
# 46            26.2                         110
# 47            29.0                         473
# 48            27.5                         543
# 49            23.3                         121
# 50            25.0                         233
# 51            27.1                         493
# 52            28.1                          89
# 53            27.2                         780
# 54            25.0                          87
# 55            25.6                         242
# 56            27.1                         970
# 57            27.9                         820
# 58            28.4                         221
# 59            25.5                         168
# 60            24.1                         203
# 61            26.5                         102
# 62            25.6                         302
# 63            24.0                         225
# 64            26.1                         891
# 65            25.2                         139
# 66            27.7                          95
# 67            24.1                         448
# 68            27.7                          92
# 69            28.7                         199
# 70            27.3                         680
# 71            26.2                         346
# 72            23.0                         139
# 73            25.6                         107
# 74            25.5                         119
# 75            28.3                         374
# 76            25.8                         166
# 77            27.9                         112
# 78            27.0                         253
# 79            27.2                         129
# 80            26.1                         230
# 81            25.8                         113
# 82            25.7                         178
# 83            27.6                         280
# 84            27.7                         467
# 85            23.7                         183
# 86            26.1                         167
# 87            25.6                         627
# 88            25.7                         182
# 89            27.3                         109
# 90            27.9                          93
# 91            27.4                         195
# 92            25.7                         232
# 93            23.5                         157
# 94            25.3                         257
# 95            28.1                         301
# 96            28.2                         131
# 97            28.9                         319
# 98            26.4                         346
# 99            27.2                         156
#
#     avg_markt_val_of_player_in_mil_£  markt_val_top_18_players_in_mil_£
